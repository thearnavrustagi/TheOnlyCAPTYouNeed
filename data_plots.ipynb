# %%
import matplotlib.pyplot as plt
import numpy as np
import librosa

# %%
fname = "final_dataset/train/l1/audio/mss-1552-v0.npy"
data = np.load(fname)

# %%
librosa.display.specshow(data, sr=16000)
